# %% [markdown]
# # Final Experiment for Diploma thesis Bitcoin price prediction

# %% [markdown]
# #### Load all own need ipynb

# %%
# %run Imports.ipynb
# %run DataFrameBuilder.ipynb
# %run ModelBuilder.ipynb
# %run ModelEvaluator.ipynb
# %run Trader.ipynb
# Out:
# C:\Users\kriza\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def RefreshImports():
    # %run Imports.ipynb
    # %run DataFrameBuilder.ipynb
    # %run ModelBuilder.ipynb
    # %run ModelEvaluator.ipynb
    # %run Trader.ipynb

# %% [markdown]
# # Porovnanie základných a interpolovaných dát cien Nvidie

# %%
df = pd.read_csv('data/data_e1.csv')
dfl = pd.read_csv('data/cleardata.csv', encoding='utf-16')
dfl = dfl.head(4776)

# %%
plt.figure(figsize = (14,4))
plt.title(f'Vývoj ceny akcií Nvidia - denné dáta', fontsize = 20)
plt.xlabel("Pozorované dni", fontsize = 18)
plt.ylabel("Cena v $", fontsize = 18)
plt.grid(True)
plt.plot(df.nvidia_price, label='Cena akcií Nvidia')
plt.legend(loc="upper right", prop={'size' : 16})
plt.figure(figsize = (14,4))

plt.title(f'Vývoj ceny akcií Nvidia - interpolované hodinové dáta', fontsize = 20)
plt.xlabel("Pozorované hodiny", fontsize = 18)
plt.ylabel("Cena v $", fontsize = 18)
plt.grid(True)
plt.plot(dfl.nvidia_price, label='Cena akcií Nvidia')
plt.legend(loc="upper right", prop={'size': 16})

# %% [markdown]
# # Porovnanie ceny BTC na dennej a hodinovej granularite

# %%
df = pd.read_csv('data/data_e1.csv')
dfl = pd.read_csv('data/cleardata.csv', encoding='utf-16')
dfl = dfl.head(4776)

# %%
plt.figure(figsize = (14,4))
plt.title(f'Vývoj ceny Bitcoinu - denné dáta', fontsize = 20)
plt.xlabel("Pozorované dni", fontsize = 18)
plt.ylabel("Cena v $", fontsize = 18)
plt.grid(True)
plt.plot(df.close_price, label='Cena Bitcoinu')
plt.legend(loc="upper right", prop={'size' : 16})
plt.figure(figsize = (14,4))

plt.title(f'Vývoj ceny Bitcoinu - hodinové dáta', fontsize = 20)
plt.xlabel("Pozorované hodiny", fontsize = 18)
plt.ylabel("Cena v $", fontsize = 18)
plt.grid(True)
plt.plot(dfl.price_close, label='Cena Bitcoinu')
plt.legend(loc="upper right", prop={'size' : 16})

# %% [markdown]
# # Porovnanie početností tried BTC na dennej a hodinovej granularite

# %%
df = pd.read_csv('data/data_e1.csv')
dfl = pd.read_csv('data/cleardata.csv', encoding='utf-16')

# %%
df['target'] = df.close_price.diff()
df['target'] =  np.where(df['target']>0, 'Rise', 'Fall')
dfl['target'] = dfl.price_close.diff()
dfl['target'] =  np.where(dfl['target']>0, 'Rise', 'Fall')

# %%
fig, ax =plt.subplots(1,2,figsize = (14,4))
ax[0].set_title(f'Početnosť tried nárast a pokles \n Denná granularita', fontsize = 19)

plt.grid(True)
sns.countplot(df.target, ax=ax[0] )
ax[0].set_xlabel(" ", fontsize = 16)
ax[0].set_ylabel("Počet pozorovaní", fontsize = 16)

ax[1].set_title(f'Početnosť tried nárast a pokles \n Hodinová granularita', fontsize = 19)
plt.grid(True)
sns.countplot(dfl.target, ax=ax[1])
ax[1].set_xlabel(" ", fontsize = 16)
ax[1].set_ylabel("Počet pozorovaní", fontsize = 16)

fig.show()

# %% [markdown]
# # Vytvorenie .csv pre výsledky gridsearchu

# %%
#df = Create2ClassResultDataframe()
#SaveTwoClassResult(df)

# %%
df=Create3ClassResultDataframe()

# %%
SaveThreeClassResult(df)

# %%
no_sample= 6

# %% [markdown]
# # Binary Classification - RF
#
#  - Gridsearch pre binárnu klasifikáciu RF
#  - 10 behov s random splitom pre vyššiu relevantnosť výsledkov
#  - možná aj cross validácia

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,5,10,15]
max_depth = [ x for x in range(5,15) ]
min_samples_split = [ x for x in range(2,6) ]
min_samples_leaf = [ x for x in range(1,6) ]

# %%
count = (len(window_size)*len(max_depth)*len(min_samples_leaf)*len(min_samples_split))
for i in tqdm(window_size):
    for j in max_depth:
        for k in min_samples_split:
            for l in min_samples_leaf:
                y_testm = []
                y_predm = []
                count = count - 1 
                print(">>>>"+str(count) + "<<<<<<", end='\r')
                if(i == 0):
                    df = LoadDifferencedDatasetForTwoClass()
                else:
                    df = LoadDifferencedDatasetForTwoClass()
                    df = CreateSlidingWindows(df, windowsize= i)
                for s in range(0, no_sample):    
                    y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier = RandomForestClassifier(n_estimators=101, max_depth=j, min_samples_split=k, min_samples_leaf = l ), test_size=0.2)
                    y_testm.append(y_test)
                    y_predm.append(y_pred)
                
                model = 'Random Forest'
                param = f'window_size: {i}  max_depth: {j} min_samples_split: {k} min_samples_leaf: {l}'
                resultDf = CreateMultipleResultAndAppend(resultDf, model, param, y_testm, y_predm)
                SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - RF

# %%
no_sample= 6

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,5,10,15]
max_depth = [ x for x in range(5,15) ]
min_samples_split = [ x for x in range(2,6) ]
min_samples_leaf = [ x for x in range(1,6) ]

# %%
count = (len(window_size)*len(max_depth)*len(min_samples_leaf)*len(min_samples_split))
for i in tqdm(window_size):
    for j in max_depth:
        for k in min_samples_split:
            for l in min_samples_leaf:
                count = count - 1 
                y_testm = []
                y_predm = []
                print(">>>>"+str(count) + "<<<<<<", end='\r')
                if(i == 0):
                    df = LoadDifferencedDatasetForThreeClass()
                else:
                    df = LoadDifferencedDatasetForThreeClass()
                    df = CreateSlidingWindows(df, windowsize= i)
                    
                for s in range(0, no_sample):   
                    y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier = RandomForestClassifier(n_estimators=101, max_depth=j, min_samples_split=k, min_samples_leaf = l ), test_size=0.2)
                    y_testm.append(y_test)
                    y_predm.append(y_pred)
                    
                model = 'Random Forest'
                param = f'window_size: {i}  max_depth: {j} min_samples_split: {k} min_samples_leaf: {l}'
                resultDf = CreateMultipleResultAndAppendThreeClass(resultDf, model, param, y_testm, y_predm)
                SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary Classification - GNB

# %%
no_sample = 5

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in tqdm(window_size):
    y_testm = []
    y_predm = []
    count = count - 1 
    print(">>>>"+str(count) + "<<<<<<", end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForTwoClass()
    else:
        df = LoadDifferencedDatasetForTwoClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    for s in range(0, no_sample):
        y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =  GaussianNB(), test_size=0.2 )    
        y_testm.append(y_test)
        y_predm.append(y_pred)
    
    model = 'GaussianNB'
    param = f'window_size: {i}'
    resultDf = CreateMultipleResultAndAppend(resultDf, model, param, y_testm, y_predm)
    SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - GNB

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in tqdm(window_size):
    count = count - 1 
    y_testm = []
    y_predm = []
    print(">>>>"+str(count) + "<<<<<<", end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForThreeClass()
    else:
        df = LoadDifferencedDatasetForThreeClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    for s in range(0, no_sample):  
        y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =  GaussianNB(), test_size=0.2 ) 
        y_testm.append(y_test)
        y_predm.append(y_pred)
    
    model = 'GaussianNB'
    param = f'window_size: {i}'
    resultDf = CreateMultipleResultAndAppendThreeClass(resultDf, model, param, y_testm, y_predm)
    SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary Classification - SVC

# %%
no_sample = 5

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in tqdm(window_size):
    y_testm = []
    y_predm = []
    count = count - 1 
    print(">>>>"+str(count) + "<<<<<<", end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForTwoClass()
    else:
        df = LoadDifferencedDatasetForTwoClass()
        df = CreateSlidingWindows(df, windowsize= i)
    for s in range(0, no_sample):
        y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =svm.SVC(gamma='scale') , test_size=0.2 )   
        y_testm.append(y_test)
        y_predm.append(y_pred)
        
    model = 'SVC'
    param = f'window_size: {i} gama: scale'
    resultDf = CreateMultipleResultAndAppend(resultDf, model, param, y_testm, y_predm)
    SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - SVC

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,5,10,15]

# %%
count = (len(window_size))
for i in window_size:
    count = count - 1
    y_testm = []
    y_predm = []
    print(">>>>"+str(count) + "<<<<<<", end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForThreeClass()
    else:
        df = LoadDifferencedDatasetForThreeClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    for s in range(0, no_sample):
        y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =svm.SVC(gamma='scale') , test_size=0.2 )    
        y_testm.append(y_test)
        y_predm.append(y_pred)
    
    model = 'SVC'
    param = f'window_size: {i} gama: scale'
    resultDf = CreateMultipleResultAndAppendThreeClass(resultDf, model, param, y_testm, y_predm)
    SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary Classification - KNN

# %%
no_sample = 5

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13]
n_neighbors = [ x for x in range(5,15) ]

# %%
count = (len(window_size)* len(n_neighbors))
for i in tqdm(window_size):
    for j in n_neighbors:
        y_testm = []
        y_predm = []
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetForTwoClass()
        else:
            df = LoadDifferencedDatasetForTwoClass()
            df = CreateSlidingWindows(df, windowsize= i)

        for s in range(0, no_sample):
            y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =KNeighborsClassifier(n_neighbors = j) , test_size=0.2 )    
            y_testm.append(y_test)
            y_predm.append(y_pred)

        model = 'KNN'
        param = f'window_size: {i} n_neighbors: {j}'
        resultDf = CreateMultipleResultAndAppend(resultDf, model, param, y_testm, y_predm)
        SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - KNN

# %%
no_sample = 5

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,5,10,15]
n_neighbors = [ x for x in range(5,15) ]

# %%
count = (len(window_size)* len(n_neighbors))
for i in tqdm(window_size):
    for j in n_neighbors:
        y_testm = []
        y_predm = []
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetForThreeClass()
        else:
            df = LoadDifferencedDatasetForThreeClass()
            df = CreateSlidingWindows(df, windowsize= i)

        for s in range(0, no_sample):
            y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =KNeighborsClassifier(n_neighbors = j) , test_size=0.2 )    
            y_testm.append(y_test)
            y_predm.append(y_pred)

        model = "KNN"
        param = f'window_size: {i}, n_neighbors: {j}'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary -  Linear regression - Classic approach

# %%
no_sample = 4

# %%
RefreshImports()

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13]
normalize = [True, False]

# %%
count = (len(normalize)* len(window_size))
for i in tqdm(window_size):
    for j in normalize:
        y_testm = []
        y_predm = []
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)
            
        for s in range(0, no_sample):
            y_test , y_pred = RegressionClassicPredictTwoClass(df, train_ratio=0.80)
            y_testm.append(y_test)
            y_predm.append(y_pred)

        model = 'Linear Regression'
        param = f'window_size: {i} normalize: {j}'
        resultDf = CreateMultipleResultAndAppend(resultDf, model, param, y_testm, y_predm)
        SaveTwoClassResult(resultDf)

# %% [markdown]
# # Linear regression - Classic approach

# %%
RefreshImports()

# %%
resultDf = OpenRegressionResultDataframe()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_true , y_pred = Regression(df, train_ratio=0.80)
        
        evs  = explained_variance_score(y_true, y_pred)
        me = max_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        #msle = mean_squared_log_error(y_true, y_pred)
        meae = median_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        #mpd = mean_poisson_deviance(y_true, y_pred)
        #mgd = mean_gamma_deviance(y_true, y_pred)
        #mtd = mean_tweedie_deviance(y_true, y_pred, power=1)
        
        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j}'
        resultDf = AppendToRegressionDataframe(resultDf, model, param, evs, me, mae, mse, meae, r2)
        SaveRegressionResultDataframe(resultDf)

# %% [markdown]
# # 3Class -  Linear regression - Classic approach

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,5,10,15]
normalize = [True, False]

# %%
count = (len(normalize)* len(window_size))
for i in tqdm(window_size):
    for j in normalize:
        y_testm = []
        y_predm = []
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        for s in range(0, no_sample):
            y_test , y_pred = RegressionClassicPredictThreeClass(df, train_ratio=0.80)
            y_testm.append(y_test)
            y_predm.append(y_pred)
        
        model = 'Linear Regression'
        param = f'window_size: {i} normalize: {j}'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # Linear regression - Rolling approach

# %%
RefreshImports()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
resultDf = OpenRegressionResultDataframe()

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_true , y_pred = RegressionRolling(df, train_ratio=0.80)

        evs  = explained_variance_score(y_true, y_pred)
        me = max_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        #msle = mean_squared_log_error(y_true, y_pred)
        meae = median_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        #mpd = mean_poisson_deviance(y_true, y_pred)
        #mgd = mean_gamma_deviance(y_true, y_pred)
        #mtd = mean_tweedie_deviance(y_true, y_pred, power=1)
        
        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j} rolling approach'
        resultDf = AppendToRegressionDataframe(resultDf, model, param, evs, me, mae, mse, meae, r2)
        SaveRegressionResultDataframe(resultDf)

# %% [markdown]
# # Binary Linear regression - Rolling approach

# %%
RefreshImports()

# %%
no_sample = 5

# %%
window_size = [ 0,1,2,3,5,8,13]
normalize = [True, False]

# %%
resultDf = OpenTwoClassResult()

# %%
count = (len(normalize)* len(window_size))
for i in tqdm(window_size):
    for j in normalize:
        y_testm = []
        y_predm = []
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        for s in range(0, no_sample):
            y_test , y_pred = RegressionRollingPredictTwoClass(df, train_ratio=0.80)
            y_testm.append(y_test)
            y_predm.append(y_pred)
        
        model = 'Linear Regression'
        param = f'window_size: {i} normalize: {j} rolling approach'
        resultDf = CreateMultipleResultAndAppend(resultDf, model, param, y_testm, y_predm)
        SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Linear regression - Rolling approach

# %%
RefreshImports()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
resultDf = OpenThreeClassResult()

# %%
count = (len(normalize)* len(window_size))
for i in tqdm(window_size):
    for j in normalize:
        y_testm = []
        y_predm = []
        count = count - 1 
        print(">>>>"+str(count) + "<<<<<<", end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        for s in range(0, no_sample):
            y_test , y_pred = RegressionRollingPredictThreeClass(df, train_ratio=0.80)
            y_testm.append(y_test)
            y_predm.append(y_pred)
            
        model = 'Linear Regression'
        param = f'window_size: {i} normalize: {j} rolling approach'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # ARIMA Model - 2Class
# ### Think about your life before u runt it

# %%
RefreshImports()

# %%
resultDf = OpenTwoClassResult()

# %%
p_values = [0, 1, 2, 4, 6] #[0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)

# %%
for i in p_values:
    for j in d_values:
        for k in q_values:
            try:
                df = LoadDifferencedDatasetWithTarget(replace_old=True, target = 'percentage')
                y_test , y_pred = DefArima(df, splitRatio = 0.8, p = i, d = j, q = k)
            except:
                print(f'fail at {i} {j} {k}')
                continue           
            model = 'ARIMA'
            param = f'p: {i} d: {j} q: {k}'
            resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
            SaveTwoClassResult(resultDf)

# %% [markdown]
# # ARIMA Model - 3Class
# ### Think about your life before u runt it

# %%
RefreshImports()

# %%
resultDf = OpenThreeClassResult()

# %%
p_values = [0, 1, 2, 4, 6] #[0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)

# %%
for i in p_values:
    for j in d_values:
        for k in q_values:
            try:
                df = LoadDifferencedDatasetWithTarget(replace_old=True, target = 'percentage')
                y_test , y_pred = DefArima3Class(df, splitRatio = 0.8, p = i, d = j, q = k)
            except:
                print(f'fail at {i} {j} {k}')
                continue  
            
            model = "ARIMA"
            param = f'p: {i}, d: {j}, q: {k}'
            resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
            SaveThreeClassResult(resultDf)

# %% [markdown]
# # ARIMA Model -Regression
# ### Think about your life before u runt it

# %%
RefreshImports()

# %%
resultDf = OpenRegressionResultDataframe()

# %%
p_values = [0, 1, 2, 4, 6] #[0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)

# %%
for i in p_values:
    for j in d_values:
        for k in q_values:
            try:
                df = LoadDifferencedDatasetWithTarget(replace_old=True, target = 'percentage')
                y_true , y_pred = DefArimaRegression(df, splitRatio = 0.8, p = i, d = j, q = k)
            except:
                print(f'fail at {i} {j} {k}')
                continue  
            
            evs  = explained_variance_score(y_true, y_pred)
            me = max_error(y_true, y_pred)
            mae = mean_absolute_error(y_true, y_pred)
            mse = mean_squared_error(y_true, y_pred)
            meae = median_absolute_error(y_true, y_pred)
            r2 = r2_score(y_true, y_pred)
            
            model = "ARIMA"
            param = f'p: {i}, d: {j}, q: {k}'
            resultDf = AppendToRegressionDataframe(resultDf, model, param, evs, me, mae, mse, meae, r2)
            SaveRegressionResultDataframe(resultDf)

# %% [markdown]
# # Analyse results for binary prediction

# %%
resultDf = OpenTwoClassResult()

# %%
resultDf[resultDf['Model'] == 'Random Forest'].sort_values('Accuracy', ascending=False).head(3)
# Out:
#              Model                                         Parameters  \
# 208  Random Forest  window_size: 1  max_depth: 5 min_samples_split...
# 55   Random Forest  window_size: 0  max_depth: 7 min_samples_split...
# 10   Random Forest  window_size: 0  max_depth: 5 min_samples_split...
#
#      Accuracy  PrecisionRise  PrecisionFall  RecallRise  RecalFall    F1Rise  \
# 208  0.582958       0.575506       0.597800    0.711385   0.449172  0.635732
# 55   0.580296       0.578470       0.584805    0.667737   0.489533  0.619287
# 10   0.580155       0.584216       0.575707    0.665937   0.488316  0.621902
#
#        F1Fall
# 208  0.511962
# 55   0.531974
# 10   0.527687

# %%
resultDf[resultDf['Model'] == 'ARIMA'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'KNN'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'SVC'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'GaussianNB'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'Linear Regression'].sort_values('Accuracy', ascending=False).head(3)

# %% [markdown]
# # Analyse results for three class prediction

# %%
resultDf = OpenThreeClassResult()

# %%
resultDf[resultDf['Model'] == 'Random Forest'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'ARIMA'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'KNN'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'SVC'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'GaussianNB'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf[resultDf['Model'] == 'Linear Regression'].sort_values('Accuracy', ascending=False).head(3)

# %%
resultDf = OpenRegressionResultDataframe()

# %%
resultDf.sort_values('mean_absolute_error', ascending=True).head(3)
#best O
# Out:
#                 Model                                         Parameters  \
# 37  Linear Regression   window_size: 0, normalize: True rolling approach
# 38  Linear Regression  window_size: 0, normalize: False rolling approach
# 22  Linear Regression                   window_size: 0, normalize: False
#
#     explained_variance_score  max_error  mean_absolute_error  \
# 37                  0.115388  24.842097             0.532390
# 38                  0.115388  24.842097             0.532390
# 22                  0.111182  24.811791             0.536215
#
#     mean_squared_error  median_absolute_error  r2_score
# 37            1.381433               0.293383  0.115304
# 38            1.381433               0.293383  0.115304
# 22            1.389043               0.297454  0.110431

# %%
resultDf.sort_values('mean_squared_error', ascending=True).head(50)
#best O
# Out:
#                 Model                                         Parameters  \
# 1               ARIMA                                   p: 0, d: 0, q: 1
# 2               ARIMA                                   p: 0, d: 0, q: 2
# 8               ARIMA                                   p: 1, d: 0, q: 1
# 12              ARIMA                                   p: 2, d: 0, q: 1
# 15              ARIMA                                   p: 4, d: 0, q: 0
# 17              ARIMA                                   p: 4, d: 0, q: 2
# 16              ARIMA                                   p: 4, d: 0, q: 1
# 19              ARIMA                                   p: 4, d: 1, q: 1
# 11              ARIMA                                   p: 2, d: 0, q: 0
# 7               ARIMA                                   p: 1, d: 0, q: 0
# 38  Linear Regression  window_size: 0, normalize: False rolling approach
# 37  Linear Regression   window_size: 0, normalize: True rolling approach
# 20  Linear Regression                    window_size: 0, normalize: True
# 21  Linear Regression                    window_size: 0, normalize: True
# 22  Linear Regression                   window_size: 0, normalize: False
# 39  Linear Regression   window_size: 1, normalize: True rolling approach
# 40  Linear Regression  window_size: 1, normalize: False rolling approach
# 41  Linear Regression   window_size: 2, normalize: True rolling approach
# 42  Linear Regression  window_size: 2, normalize: False rolling approach
# 44  Linear Regression  window_size: 3, normalize: False rolling approach
# 43  Linear Regression   window_size: 3, normalize: True rolling approach
# 46  Linear Regression  window_size: 5, normalize: False rolling approach
# 45  Linear Regression   window_size: 5, normalize: True rolling approach
# 24  Linear Regression                   window_size: 1, normalize: False
# 23  Linear Regression                    window_size: 1, normalize: True
# 25  Linear Regression                    window_size: 2, normalize: True
# 26  Linear Regression                   window_size: 2, normalize: False
# 27  Linear Regression                    window_size: 3, normalize: True
# 28  Linear Regression                   window_size: 3, normalize: False
# 48  Linear Regression  window_size: 8, normalize: False rolling approach
# 47  Linear Regression   window_size: 8, normalize: True rolling approach
# 29  Linear Regression                    window_size: 5, normalize: True
# 30  Linear Regression                   window_size: 5, normalize: False
# 49  Linear Regression  window_size: 13, normalize: True rolling approach
# 50  Linear Regression  window_size: 13, normalize: False rolling appr...
# 0               ARIMA                                   p: 0, d: 0, q: 0
# 4               ARIMA                                   p: 0, d: 1, q: 1
# 32  Linear Regression                   window_size: 8, normalize: False
# 31  Linear Regression                    window_size: 8, normalize: True
# 34  Linear Regression                  window_size: 13, normalize: False
# 33  Linear Regression                   window_size: 13, normalize: True
# 18              ARIMA                                   p: 4, d: 1, q: 0
# 52  Linear Regression  window_size: 21, normalize: False rolling appr...
# 51  Linear Regression  window_size: 21, normalize: True rolling approach
# 35  Linear Regression                   window_size: 21, normalize: True
# 36  Linear Regression                  window_size: 21, normalize: False
# 13              ARIMA                                   p: 2, d: 1, q: 0
# 9               ARIMA                                   p: 1, d: 1, q: 0
# 3               ARIMA                                   p: 0, d: 1, q: 0
# 6               ARIMA                                   p: 0, d: 2, q: 1
#
#     explained_variance_score  max_error  mean_absolute_error  \
# 1                   0.137300  25.083497             0.536626
# 2                   0.136161  25.084547             0.536798
# 8                   0.136013  25.084651             0.536817
# 12                  0.135725  25.082278             0.536790
# 15                  0.134680  25.081570             0.537157
# 17                  0.134353  25.050235             0.539246
# 16                  0.134190  25.061385             0.537749
# 19                  0.135255  25.149719             0.537829
# 11                  0.132775  25.079003             0.537363
# 7                   0.120046  25.052918             0.537880
# 38                  0.115388  24.842097             0.532390
# 37                  0.115388  24.842097             0.532390
# 20                  0.111182  24.811791             0.536215
# 21                  0.111182  24.811791             0.536215
# 22                  0.111182  24.811791             0.536215
# 39                  0.100278  24.814497             0.541479
# 40                  0.100278  24.814497             0.541479
# 41                  0.099545  24.808327             0.546946
# 42                  0.099545  24.808327             0.546946
# 44                  0.090858  24.882895             0.552718
# 43                  0.090858  24.882895             0.552718
# 46                  0.080574  25.050086             0.559616
# 45                  0.080574  25.050086             0.559616
# 24                  0.076703  24.789125             0.548408
# 23                  0.076703  24.789125             0.548408
# 25                  0.075565  24.799020             0.554816
# 26                  0.075565  24.799020             0.554816
# 27                  0.061439  24.886895             0.562816
# 28                  0.061439  24.886895             0.562816
# 48                  0.039402  25.069181             0.585812
# 47                  0.039402  25.069181             0.585812
# 29                  0.037153  25.110598             0.572454
# 30                  0.037153  25.110598             0.572454
# 49                  0.004404  24.983551             0.618955
# 50                  0.004404  24.983551             0.618955
# 0                  -0.000176  24.975577             0.539400
# 4                  -0.000750  25.022900             0.540516
# 32                 -0.031951  25.120071             0.605125
# 31                 -0.031951  25.120071             0.605125
# 34                 -0.060787  25.024325             0.642095
# 33                 -0.060787  25.024325             0.642095
# 18                 -0.104097  25.064085             0.626901
# 52                 -0.120900  25.136189             0.675232
# 51                 -0.120900  25.136189             0.675232
# 35                 -0.244030  25.192609             0.710570
# 36                 -0.244030  25.190572             0.710650
# 13                 -0.333548  24.763819             0.676910
# 9                  -0.643578  30.150262             0.736308
# 3                  -1.738864  45.029938             0.898696
# 6                  -1.739819  45.038948             0.898859
#
#     mean_squared_error  median_absolute_error  r2_score
# 1             1.347162               0.280134  0.137253
# 2             1.348947               0.278368  0.136109
# 8             1.349178               0.278285  0.135961
# 12            1.349632               0.279873  0.135671
# 15            1.351268               0.281622  0.134623
# 17            1.351782               0.281375  0.134294
# 16            1.352031               0.279661  0.134134
# 19            1.353047               0.288723  0.133484
# 11            1.354232               0.281479  0.132725
# 7             1.374098               0.285159  0.120002
# 38            1.381433               0.293383  0.115304
# 37            1.381433               0.293383  0.115304
# 20            1.389043               0.297454  0.110431
# 21            1.389043               0.297454  0.110431
# 22            1.389043               0.297454  0.110431
# 39            1.404071               0.299270  0.100245
# 40            1.404071               0.299270  0.100245
# 41            1.405325               0.307205  0.099441
# 42            1.405325               0.307205  0.099441
# 44            1.418935               0.306388  0.090719
# 43            1.418935               0.306388  0.090719
# 46            1.435362               0.315359  0.080193
# 45            1.435362               0.315359  0.080193
# 24            1.441787               0.304998  0.076076
# 23            1.441787               0.304998  0.076076
# 25            1.442599               0.315089  0.075555
# 26            1.442599               0.315089  0.075555
# 27            1.464694               0.316045  0.061397
# 28            1.464694               0.316045  0.061397
# 48            1.500371               0.335877  0.039202
# 47            1.500371               0.335877  0.039202
# 29            1.504544               0.312321  0.035860
# 30            1.504544               0.312321  0.035860
# 49            1.555866               0.359565  0.004366
# 50            1.555866               0.359565  0.004366
# 0             1.561791               0.288258 -0.000200
# 4             1.563780               0.294006 -0.001474
# 32            1.611485               0.344621 -0.031952
# 31            1.611485               0.344621 -0.031952
# 34            1.658469               0.365230 -0.061292
# 33            1.658469               0.365230 -0.061292
# 18            1.724024               0.354827 -0.104097
# 52            1.754069               0.409690 -0.120968
# 51            1.754069               0.409690 -0.120968
# 35            1.947060               0.410234 -0.244302
# 36            1.947162               0.410024 -0.244368
# 13            2.082307               0.385356 -0.333548
# 9             2.566412               0.418304 -0.643578
# 3             4.276679               0.513810 -1.738865
# 6             4.278170               0.513924 -1.739820

# %%
resultDf.sort_values('median_absolute_error', ascending=True).head(3)
#best O

# %%
resultDf.sort_values('r2_score', ascending=False).head(3)
#best 1

# %% [markdown]
# # Train best RF MODEL

# %% [markdown]
# ### Check best param

# %%
RefreshImports()

# %%
pd.options.display.max_colwidth = 150
resultDf[resultDf['Model'] == 'Random Forest'].sort_values('Accuracy', ascending=False).head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e197c496c998> in <module>
#       1 pd.options.display.max_colwidth = 150
# ----> 2 resultDf[resultDf['Model'] == 'Random Forest'].sort_values('Accuracy', ascending=False).head(2)
#
# NameError: name 'resultDf' is not defined

# %%
df = LoadTradeDataset2Class()

# %%
bilance = SimulateTrade(df, steps=False)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 45.65% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 38.35% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 52.92% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -15.69% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -11.01% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 86.36% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 47.57% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 6.4% =============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 17.78% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 3.44% ============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -34.04% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 16.61% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -30.05% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 29.98% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 22.25% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 49.67% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 27.47% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 13.93% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 24.28% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -6.76% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 58.78% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -22.26% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -14.45% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 106.16% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 12.14% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 21.25% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -28.73% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 46.46% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -9.09% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 36.25% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 21.75% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 16.54% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -38.85% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 1.3% =============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -32.53% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -1.83% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 77.19% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 27.0% ============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -25.86% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 124.2% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -32.99% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 151.7% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 116.73% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 44.61% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -15.17% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -23.75% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -27.32% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -31.15% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 28.22% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -34.0% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 11.75% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -18.93% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -4.84% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 56.58% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 74.58% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -26.57% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -4.59% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 11.69% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 15.94% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -29.45% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 52.47% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -20.3% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 22.93% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -21.97% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 35.58% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 77.8% ============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 19.86% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -11.12% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -12.91% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 44.48% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 10.09% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -29.86% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -0.12% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 35.35% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -29.6% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 29.8% ============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 39.08% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 29.8% ============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 2.82% ============================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 115.17% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 91.36% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -23.18% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 35.09% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -4.78% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -23.05% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 51.57% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 88.61% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -28.08% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 13.64% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 58.28% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 41.61% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 10.25% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 22.93% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -10.7% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 44.26% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -15.77% ==========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 90.07% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 15.01% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== -9.35% ===========================
# HBox(children=(FloatProgress(value=0.0, max=1421.0), HTML(value='')))
# ======================= GLOBAL BALANCE =======================
# =========================== 161.77% ==========================
#
# 20.224599999999995%
