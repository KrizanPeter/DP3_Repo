# %% [markdown]
# # Final Experiment for Diploma thesis Bitcoin price prediction

# %% [markdown]
# #### Load all own need ipynb

# %%
# %run Imports.ipynb
# %run DataFrameBuilder.ipynb
# %run ModelBuilder.ipynb
# %run ModelEvaluator.ipynb

# %%
def RefreshImports():
    # %run Imports.ipynb
    # %run DataFrameBuilder.ipynb
    # %run ModelBuilder.ipynb
    # %run ModelEvaluator.ipynb

# %%
SaveTwoClassResult(resultDf)

# %% [markdown]
# # Binary Classification - RF

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
max_depth = [ x for x in range(5,15) ]
min_samples_split = [ x for x in range(2,6) ]
min_samples_leaf = [ x for x in range(1,6) ]

# %%
count = (len(window_size)*len(max_depth)*len(min_samples_leaf)*len(min_samples_split))
for i in window_size:
    for j in max_depth:
        for k in min_samples_split:
            for l in min_samples_leaf:
                count = count - 1 
                print(">>>>"+str(count) + "<<<<<<", end='\r')
                if(i == 0):
                    df = LoadDifferencedDatasetForTwoClass()
                else:
                    df = LoadDifferencedDatasetForTwoClass()
                    df = CreateSlidingWindows(df, windowsize= i)
                    
                y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier = RandomForestClassifier(n_estimators=101, max_depth=j, min_samples_split=k, min_samples_leaf = l ), test_size=0.2)
                model = "Random Forest"
                param = f'window_size: {i} , max_depth: {j} ,min_samples_split: {k} ,min_samples_leaf: {l}'
                resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
                SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - RF

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
max_depth = [ x for x in range(5,15) ]
min_samples_split = [ x for x in range(2,6) ]
min_samples_leaf = [ x for x in range(1,6) ]

# %%
count = (len(window_size)*len(max_depth)*len(min_samples_leaf)*len(min_samples_split))
for i in window_size:
    for j in max_depth:
        for k in min_samples_split:
            for l in min_samples_leaf:
                count = count - 1 
                print(">>>>"+str(count) + "<<<<<<", end='\r')
                if(i == 0):
                    df = LoadDifferencedDatasetForThreeClass()
                else:
                    df = LoadDifferencedDatasetForThreeClass()
                    df = CreateSlidingWindows(df, windowsize= i)
                    
                y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier = RandomForestClassifier(n_estimators=101, max_depth=j, min_samples_split=k, min_samples_leaf = l ), test_size=0.2)
                model = "Random Forest"
                param = f'window_size: {i} , max_depth: {j} ,min_samples_split: {k} ,min_samples_leaf: {l}'
                resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
                SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary Classification - GNB

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in window_size:
    count = count - 1 
    print(count, end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForTwoClass()
    else:
        df = LoadDifferencedDatasetForTwoClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =  GaussianNB(), test_size=0.2 )    
    model = "GaussianNB"
    param = f'window_size: {i}'
    resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
    SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - GNB

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in window_size:
    count = count - 1 
    print(count, end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForThreeClass()
    else:
        df = LoadDifferencedDatasetForThreeClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =  GaussianNB(), test_size=0.2 )    
    model = "GaussianNB"
    param = f'window_size: {i}'
    resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
    SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary Classification - SVC

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in window_size:
    count = count - 1 
    print(count, end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForTwoClass()
    else:
        df = LoadDifferencedDatasetForTwoClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =svm.SVC(gamma='scale') , test_size=0.2 )    
    model = "SVC"
    param = f'window_size: {i}, gama: scale'
    resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
    SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - SVC

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]

# %%
count = (len(window_size))
for i in window_size:
    count = count - 1 
    print(count, end='\r')
    if(i == 0):
        df = LoadDifferencedDatasetForThreeClass()
    else:
        df = LoadDifferencedDatasetForThreeClass()
        df = CreateSlidingWindows(df, windowsize= i)
    
    y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =svm.SVC(gamma='scale') , test_size=0.2 )    
    model = "SVC"
    param = f'window_size: {i}, gama: scale'
    resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
    SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary Classification - KNN

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
n_neighbors = [ x for x in range(5,15) ]

# %%
count = (len(window_size)* len(n_neighbors))
for i in window_size:
    for j in n_neighbors:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetForTwoClass()
        else:
            df = LoadDifferencedDatasetForTwoClass()
            df = CreateSlidingWindows(df, windowsize= i)

        y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =KNeighborsClassifier(n_neighbors = j) , test_size=0.2 )    
        model = "KNN"
        param = f'window_size: {i}, n_neighbors: {j}'
        resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
        SaveTwoClassResult(resultDf)

# %% [markdown]
# # 3Class Classification - KNN

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
n_neighbors = [ x for x in range(5,15) ]

# %%
count = (len(window_size)* len(n_neighbors))
for i in window_size:
    for j in n_neighbors:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetForThreeClass()
        else:
            df = LoadDifferencedDatasetForThreeClass()
            df = CreateSlidingWindows(df, windowsize= i)

        y_test , y_pred = Predict(df,scaler = StandardScaler(), classifier =KNeighborsClassifier(n_neighbors = j) , test_size=0.2 )    
        model = "KNN"
        param = f'window_size: {i}, n_neighbors: {j}'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # Binary -  Linear regression - Classic approach

# %%
RefreshImports()

# %%
resultDf = OpenTwoClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_test , y_pred = RegressionClassicPredictTwoClass(df, train_ratio=0.80)

        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j}'
        resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
        SaveTwoClassResult(resultDf)

# %% [markdown]
# # Linear regression - Classic approach

# %%
RefreshImports()

# %%
resultDf = OpenRegressionResultDataframe()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_true , y_pred = Regression(df, train_ratio=0.80)
        
        evs  = explained_variance_score(y_true, y_pred)
        me = max_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        #msle = mean_squared_log_error(y_true, y_pred)
        meae = median_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        #mpd = mean_poisson_deviance(y_true, y_pred)
        #mgd = mean_gamma_deviance(y_true, y_pred)
        #mtd = mean_tweedie_deviance(y_true, y_pred, power=1)
        
        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j}'
        resultDf = AppendToRegressionDataframe(resultDf, model, param, evs, me, mae, mse, meae, r2)
        SaveRegressionResultDataframe(resultDf)
# Out:
# 00

# %% [markdown]
# # 3Class -  Linear regression - Classic approach

# %%
resultDf = OpenThreeClassResult()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_test , y_pred = RegressionClassicPredictThreeClass(df, train_ratio=0.80)

        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j}'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # Linear regression - Rolling approach

# %%
RefreshImports()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
resultDf = OpenRegressionResultDataframe()

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_true , y_pred = RegressionRollingPredictTwoClass(df, train_ratio=0.80)

        evs  = explained_variance_score(y_true, y_pred)
        me = max_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        #msle = mean_squared_log_error(y_true, y_pred)
        meae = median_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        #mpd = mean_poisson_deviance(y_true, y_pred)
        #mgd = mean_gamma_deviance(y_true, y_pred)
        #mtd = mean_tweedie_deviance(y_true, y_pred, power=1)
        
        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j} rolling approach'
        resultDf = AppendToRegressionDataframe(resultDf, model, param, evs, me, mae, mse, meae, r2)
        SaveRegressionResultDataframe(resultDf)
# Out:
# 15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-7ccae2d53485> in <module>
#      12         y_true , y_pred = RegressionRollingPredictTwoClass(df, train_ratio=0.80)
#      13
# ---> 14         evs  = explained_variance_score(y_true, y_pred)
#      15         me = max_error(y_true, y_pred)
#      16         mae = mean_absolute_error(y_true, y_pred)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in explained_variance_score(y_true, y_pred, sample_weight, multioutput)
#     452     """
#     453     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 454         y_true, y_pred, multioutput)
#     455     check_consistent_length(y_true, y_pred, sample_weight)
#     456
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      87
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Fall'

# %% [markdown]
# # Binary Linear regression - Rolling approach

# %%
RefreshImports()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
resultDf = OpenThreeClassResult()

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_test , y_pred = RegressionRollingPredictThreeClass(df, train_ratio=0.80)

        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j} rolling approach'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # 3Class Linear regression - Rolling approach

# %%
RefreshImports()

# %%
window_size = [ 0,1,2,3,5,8,13,21]
normalize = [True, False]

# %%
resultDf = OpenThreeClassResult()

# %%
count = (len(normalize)* len(window_size))
for i in window_size:
    for j in normalize:
        count = count - 1 
        print(count, end='\r')
        if(i == 0):
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
        else:
            df = LoadDifferencedDatasetWithTarget(target = 'percentage')
            df = CreateSlidingWindows(df, windowsize= i)

        y_test , y_pred = RegressionRollingPredictThreeClass(df, train_ratio=0.80)

        model = "Linear Regression"
        param = f'window_size: {i}, normalize: {j} rolling approach'
        resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
        SaveThreeClassResult(resultDf)

# %% [markdown]
# # ARIMA Model - 2Class
# ### Think about your life before u runt it

# %%
RefreshImports()

# %%
resultDf = OpenTwoClassResult()

# %%
p_values = [0, 1, 2, 4, 6] #[0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)

# %%
for i in p_values:
    for j in d_values:
        for k in q_values:
            try:
                df = LoadDifferencedDatasetWithTarget(replace_old=True, target = 'percentage')
                y_test , y_pred = DefArima(df, splitRatio = 0.8, p = i, d = j, q = k)
            except:
                print(f'fail at {i} {j} {k}')
                continue           
            model = "ARIMA"
            param = f'p: {i}, d: {j}, q: {k}'
            resultDf = CreateResultAndAppend(resultDf, model, param, y_test, y_pred)
            SaveTwoClassResult(resultDf)

# %% [markdown]
# # ARIMA Model - 3Class
# ### Think about your life before u runt it

# %%
RefreshImports()

# %%
resultDf = OpenThreeClassResult()

# %%
p_values = [0, 1, 2, 4, 6] #[0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)

# %%
for i in p_values:
    for j in d_values:
        for k in q_values:
            try:
                df = LoadDifferencedDatasetWithTarget(replace_old=True, target = 'percentage')
                y_test , y_pred = DefArima3Class(df, splitRatio = 0.8, p = i, d = j, q = k)
            except:
                print(f'fail at {i} {j} {k}')
                continue  
            
            model = "ARIMA"
            param = f'p: {i}, d: {j}, q: {k}'
            resultDf = CreateResultAndAppendThreeClass(resultDf, model, param, y_test, y_pred)
            SaveThreeClassResult(resultDf)

# %% [markdown]
# # CHOOSE BEST MODELS - Binary

# %%
resultDf = OpenTwoClassResult()

# %%
resultDf[resultDf['Accuracy'] == resultDf.Accuracy.max()]
# Out:
#       Model        Parameters  Accuracy  PrecisionRise  PrecisionFall  \
# 1736  ARIMA  p: 1, d: 0, q: 1  0.606615        0.60024       0.615646
#
#       PrecisionStay  RecallRise  RecalFall  RecalStay    F1Rise    F1Fall  \
# 1736            NaN    0.688705   0.520863        NaN  0.641437  0.564302
#
#       F1Stay
# 1736     NaN

# %%
resultDf[resultDf['PrecisionRise'] == resultDf.PrecisionRise.max()]
# Out:
#       Model        Parameters  Accuracy  PrecisionRise  PrecisionFall  \
# 1736  ARIMA  p: 1, d: 0, q: 1  0.606615        0.60024       0.615646
#
#       PrecisionStay  RecallRise  RecalFall  RecalStay    F1Rise    F1Fall  \
# 1736            NaN    0.688705   0.520863        NaN  0.641437  0.564302
#
#       F1Stay
# 1736     NaN

# %%
resultDf[resultDf['PrecisionFall'] == resultDf.PrecisionFall.max()]
# Out:
#       Model        Parameters  Accuracy  PrecisionRise  PrecisionFall  \
# 1736  ARIMA  p: 1, d: 0, q: 1  0.606615        0.60024       0.615646
#
#       PrecisionStay  RecallRise  RecalFall  RecalStay    F1Rise    F1Fall  \
# 1736            NaN    0.688705   0.520863        NaN  0.641437  0.564302
#
#       F1Stay
# 1736     NaN

# %%
resultDf[resultDf['RecallRise'] == resultDf.RecallRise.max()]
# Out:
#       Model        Parameters  Accuracy  PrecisionRise  PrecisionFall  \
# 1728  ARIMA  p: 0, d: 0, q: 0  0.510908       0.510908            0.0
#
#       PrecisionStay  RecallRise  RecalFall  RecalStay    F1Rise  F1Fall  \
# 1728            NaN         1.0        0.0        NaN  0.676293     0.0
#
#       F1Stay
# 1728     NaN

# %%
resultDf[resultDf['RecalFall'] == resultDf.RecalFall.max()]
# Out:
#       Model        Parameters  Accuracy  PrecisionRise  PrecisionFall  \
# 1732  ARIMA  p: 0, d: 1, q: 1  0.485574       0.142857        0.48727
#
#       PrecisionStay  RecallRise  RecalFall  RecalStay    F1Rise   F1Fall  \
# 1732            NaN    0.001377   0.991367        NaN  0.002729  0.65339
#
#       F1Stay
# 1732     NaN

# %% [markdown]
# # CHOOSE BEST MODELS - 3Class

# %%
resultDf = OpenThreeClassResult()

# %%
resultDf[resultDf['Accuracy'] == resultDf.Accuracy.max()]
# Out:
#             Model                                         Parameters  \
# 34  Random Forest  window_size: 0 , max_depth: 6 ,min_samples_spl...
#
#     Accuracy  PrecisionRise  PrecisionFall  PrecisionStay  RecallRise  \
# 34  0.453906       0.447727       0.511111       0.430931    0.399594
#
#     RecalFall  RecalStay    F1Rise    F1Fall    F1Stay
# 34   0.605485        NaN  0.422294  0.418726  0.503509

# %%
resultDf[resultDf['PrecisionRise'] == resultDf.PrecisionRise.max()]
# Out:
#              Model                                         Parameters  \
# 249  Random Forest  window_size: 1 , max_depth: 7 ,min_samples_spl...
#
#      Accuracy  PrecisionRise  PrecisionFall  PrecisionStay  RecallRise  \
# 249  0.446479       0.464758       0.449405       0.431746    0.427126
#
#      RecalFall  RecalStay    F1Rise    F1Fall    F1Stay
# 249   0.584946        NaN  0.445148  0.378921  0.496804

# %%
resultDf[resultDf['PrecisionFall'] == resultDf.PrecisionFall.max()]
# Out:
#              Model                                         Parameters  \
# 618  Random Forest  window_size: 3 , max_depth: 5 ,min_samples_spl...
#
#      Accuracy  PrecisionRise  PrecisionFall  PrecisionStay  RecallRise  \
# 618  0.427465       0.412668       0.523316       0.412181     0.46841
#
#      RecalFall  RecalStay    F1Rise    F1Fall    F1Stay
# 618   0.640969        NaN  0.438776  0.288571  0.501724

# %%
resultDf[resultDf['RecallRise'] == resultDf.RecallRise.max()]
# Out:
#               Model                                         Parameters  \
# 1419  Random Forest  window_size: 21 , max_depth: 5 ,min_samples_sp...
#
#       Accuracy  PrecisionRise  PrecisionFall  PrecisionStay  RecallRise  \
# 1419  0.420198       0.400673       0.465517       0.429178    0.501053
#
#       RecalFall  RecalStay    F1Rise    F1Fall    F1Stay
# 1419   0.644681        NaN  0.445276  0.183986  0.515306

# %%
resultDf[resultDf['RecalFall'] == resultDf.RecalFall.max()]
# Out:
#       Model        Parameters  Accuracy  PrecisionRise  PrecisionFall  \
# 1728  ARIMA  p: 0, d: 0, q: 0  0.370866            0.0            0.0
# 1732  ARIMA  p: 0, d: 1, q: 1  0.370866            0.0            0.0
#
#       PrecisionStay  RecallRise  RecalFall  RecalStay  F1Rise  F1Fall  \
# 1728       0.370866         0.0        1.0        NaN     0.0     0.0
# 1732       0.370866         0.0        1.0        NaN     0.0     0.0
#
#         F1Stay
# 1728  0.541068
# 1732  0.541068
