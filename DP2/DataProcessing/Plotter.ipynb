# %%
def GetMinMaxValue(val, min, max):
    return (val - min) / (max - min)

def GetStringLabels(cols):
    result = []
    for row in cols:
        print(row)
        result.append(str(row))
    return result

def NormalizeColumn(column):
    minv = min(column)
    maxv = max(column)
    result = []
    for col in column:
        value = GetMinMaxValue(col, minv, maxv)
        result.append(value)
    return result

def PlotBase(xlabel, ylabel):
    plt.figure(figsize=(9, 3))
